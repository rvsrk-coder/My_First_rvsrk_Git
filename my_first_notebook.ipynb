# %% [markdown]
# <a href="https://colab.research.google.com/github/rvsrk-coder/My_First_rvsrk_Git/blob/main/my_first_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# What is the difference between hardware and software? Give one example of each.
#
# Hardware is physical components of a computer. We can feel and touch. and also It is a 0 level layer to setup the powerful computing environment through next level (ie 1 level ) software
#
# Software is Set of instruction which will work thorugh using 0 level layer hardware components. we can not feel and touch.
